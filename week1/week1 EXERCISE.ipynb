# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from openai import OpenAI
import ollama
from IPython.display import Markdown, display, update_display

# %%
# constants

MODEL_GPT = "gpt-4o-mini"
MODEL_LLAMA = "llama3.2:1b"

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if api_key and api_key.startswith("sk-proj-") and len(api_key) > 10:
    print("API key looks good so far")
else:
    print(
        "There might be a problem with your API key? Please visit the troubleshooting notebook!"
    )
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
my_question = input("Enter your question: ")

# %%
# prompt
system_prompt = """
You are a helpful, intelligent assistant that can answer technical questions.
"""
user_prompt = "Please give detail explanation about this following question: "


def get_user_prompt(question):
    user_prompt = (
        "Please give detail explanation about this following question: " + question
    )
    return user_prompt

# %%
# Get gpt-4o-mini to answer, with streaming
openai = OpenAI()


def get_gpt_answer(question):
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_user_prompt(question)},
        ],
        stream=True,
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ""
        response = response.replace("```", "").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)


get_gpt_answer(input("Enter your question: "))
# Out:
# The question of which number is bigger, 1 or 2, is a straightforward comparison within the context of basic arithmetic and number theory.
#
# 1. **Understanding Numbers**:
#    - Numbers are mathematical entities that denote quantities. They can be whole numbers (integers), fractions, decimals, etc. In this case, we are looking at whole numbers.
#
# 2. **Comparison of Whole Numbers**:
#    - When comparing numbers, we often use the “greater than” (>) and “less than” (<) symbols.
#    - A number \( A \) is greater than another number \( B \) if \( A \) is located to the right of \( B \) on the number line.
#
# 3. **The Number Line**:
#    - A number line is a straight line on which numbers are represented in increasing order from left to right. For example:
#      - ... -2, -1, 0, 1, 2, 3, 4, ...
#    - In this representation, 1 is to the left of 2.
#
# 4. **Comparison**:
#    - To determine which is greater, we look at their positions:
# ...

# %%
# Get Llama 3.2 to answer
response = ollama.chat(
    model=MODEL_LLAMA,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + input("Enter your question: ")},
    ],
)
reply = response["message"]["content"]
display(Markdown(reply))
# Out:
# The answer to this question is a bit straightforward, but it depends on how you define "bigger."
#
# If we're talking about physical size, then 1 is generally bigger than 2. A standard coin, for example, is typically about 1 inch (2.54 cm) in diameter. On the other hand, a standard ruler or meter stick is usually about 2 inches (5.08 cm) long.
#
# However, if we're talking about digital size or amount, then it's a different story. For instance, if you have a digital file that's 1 megabyte (MB) in size, it's likely bigger than a file that's 2 MB in size. Similarly, if you have a digital address that's 1 street address, it's likely bigger than an address that's 2 street addresses.
#
# In general, the answer to this question depends on the context in which it's being used.
